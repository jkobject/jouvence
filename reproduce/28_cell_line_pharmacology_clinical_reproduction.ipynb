# %% [markdown]
# # Cell-line, pharmacology, and clinical context
#
# DepMap, Project Score, GDSC, PRISM, Cellosaurus, and ClinicalTrials.gov.
#
# This is explanatory reproduction plus a bounded local illustration—not a production runner. Production commands below are inert text. Code cells use only synthetic input, temporary directories, and pure tracked parsing/schema functions. They perform no shell, subprocess, network, cloud, GCS, LaminDB, canonical-path, or production-builder execution.
#
# Status describes the accepted artifact, independently of replay completeness: `canonical`, `official`, `staged`, `deferred`, or `not_reproducible_yet`.

# %% [markdown]
# <a id="source-depmap-ccle"></a>
# ## DepMap/CCLE public releases
#
# - **status:** `canonical` — canonical cell-line nodes; bounded staged 24Q2 essentiality replay from acquired Model/CRISPR files
# - **release/snapshot:** DepMap Public 24Q2 Figshare article 25880521
# - **source and access:** https://figshare.com/articles/dataset/DepMap_24Q2_Public/25880521 — Figshare immutable file IDs
# - **licence/citation:** DepMap terms and source-study citations; preserve CCLE/Gygi/Project Achilles attribution
# - **raw cache template:** `artifacts/cache/<task-id>/raw/cell_line_assays/downloads`
# - **preprocessing entrypoint:** `manage_db/build_staged_cell_line_assays.py; txdata_download.py`
# - **mapping:** exact DepMap ModelID, Entrez-to-gene and UniProt-to-protein mappings; no RNA-to-protein projection
# - **rejects/conflicts/evidence:** exact DepMap ModelID, Entrez-to-gene and UniProt-to-protein mappings; no RNA-to-protein projection
# - **validation evidence:** 28_cell_line_pharmacology_clinical_reproduction.ipynb; focused test command: uv run --group dev pytest -q tests/test_build_staged_cell_line_assays.py; exact accepted counts/checksums are not recoverable from a durable checked report where noted in gap.
# - **bounded fixture:** available. Exact accepted source-family count/checksum evidence is not present in a durable checked report; this is an explanatory gap, not evidence of zero output. Bounded demonstration is provided using a pure parser/schema function from the tracked repository.
#
# **Produced artifacts**
#   - `canonical cell-line nodes`
#   - `bounded staged 24Q2 essentiality replay from acquired Model/CRISPR files`
#
# **Manual production/acquisition command (documentation only; never executed here)**
#
# ```text
# No complete current acquisition command is tracked. Use the immutable URL/file identifiers above, record bytes and SHA-256 in a task-local manifest, then invoke the preprocessing entrypoint separately.
# ```

# %% [markdown]
# <a id="source-project-score"></a>
# ## Project Score CRISPR dependency
#
# - **status:** `deferred` — staged cell_line_gene_essentiality candidate
# - **release/snapshot:** release-selected Project Score matrix not retained in a checked manifest
# - **source and access:** https://score.depmap.sanger.ac.uk/downloads — licensed/manual Sanger download
# - **licence/citation:** Project Score terms/citation; no canonical addition claimed
# - **raw cache template:** `artifacts/cache/<task-id>/raw/cell_line_assays/project_score`
# - **preprocessing entrypoint:** `manage_db/build_staged_cell_line_assays.py`
# - **mapping:** cell-line/model and gene mappings with score/threshold rejects
# - **rejects/conflicts/evidence:** cell-line/model and gene mappings with score/threshold rejects
# - **validation evidence:** 28_cell_line_pharmacology_clinical_reproduction.ipynb; focused test command: uv run --group dev pytest -q tests/test_build_staged_cell_line_assays.py; exact accepted counts/checksums are not recoverable from a durable checked report where noted in gap.
# - **bounded fixture:** not available. Exact accepted source-family count/checksum evidence is not present in a durable checked report; this is an explanatory gap, not evidence of zero output. Project Score requires a licensed release-selected dependency matrix and model crosswalk input; the shared assay builder has no source acquisition surface for it.
#
# **Produced artifacts**
#   - `staged cell_line_gene_essentiality candidate`
#
# **Manual production/acquisition command (documentation only; never executed here)**
#
# ```text
# No command is reproducible without a licensed, release-selected Project Score matrix and model crosswalk.
# ```

# %% [markdown]
# <a id="source-gdsc"></a>
# ## GDSC/Sanger dose response
#
# - **status:** `deferred` — staged cell_line_responds_to_molecule edges/evidence
# - **release/snapshot:** GDSC1/GDSC2 release-selected local file not retained in a checked manifest
# - **source and access:** https://www.cancerrxgene.org/downloads/bulk_download — licensed/manual CancerRxGene bulk download
# - **licence/citation:** GDSC terms and Iorio et al citation; no canonical addition claimed
# - **raw cache template:** `artifacts/cache/<task-id>/raw/cell_line_assays/downloads/sanger-dose-response.csv`
# - **preprocessing entrypoint:** `manage_db/build_staged_cell_line_assays.py`
# - **mapping:** COSMIC/DepMap cell-line crosswalk and unique molecule mapping; threshold/missing mappings rejected
# - **rejects/conflicts/evidence:** COSMIC/DepMap cell-line crosswalk and unique molecule mapping; threshold/missing mappings rejected
# - **validation evidence:** 28_cell_line_pharmacology_clinical_reproduction.ipynb; focused test command: uv run --group dev pytest -q tests/test_build_staged_cell_line_assays.py; exact accepted counts/checksums are not recoverable from a durable checked report where noted in gap.
# - **bounded fixture:** not available. Exact accepted source-family count/checksum evidence is not present in a durable checked report; this is an explanatory gap, not evidence of zero output. GDSC bulk download terms and a release-selected local dose-response file must be supplied before the shared assay builder has a reproducible command.
#
# **Produced artifacts**
#   - `staged cell_line_responds_to_molecule edges/evidence`
#
# **Manual production/acquisition command (documentation only; never executed here)**
#
# ```text
# No command is reproducible without a release-selected GDSC dose-response file and reviewed access terms.
# ```

# %% [markdown]
# <a id="source-prism-20q2"></a>
# ## Broad PRISM Repurposing 20Q2 Secondary
#
# - **status:** `staged` — immutable staged viability features and cell_line_responds_to_molecule edges/evidence
# - **release/snapshot:** Broad PRISM Repurposing 20Q2 Secondary; Figshare DOI 10.6084/m9.figshare.20564034.v1
# - **source and access:** https://doi.org/10.6084/m9.figshare.20564034.v1 — Figshare v1 assets, six release-selected local tables
# - **licence/citation:** CC BY 4.0; cite Corsello et al and Figshare DOI
# - **raw cache template:** `artifacts/cache/<task-id>/prism/20q2`
# - **preprocessing entrypoint:** `honest gap: manage_db.build_staged_prism_20q2 exists only at the cited historical commit and is intentionally not retained by this rescope.`
# - **mapping:** exact ACH IDs and unique structure-derived InChIKey; names never map molecules; ambiguous structures quarantined
# - **rejects/conflicts/evidence:** exact ACH IDs and unique structure-derived InChIKey; names never map molecules; ambiguous structures quarantined
# - **validation evidence:** Historical accepted lane at commit 1cb1c314e24a1d7a1386ef1b98b9cab395557283 and reproduce/28_cell_line_pharmacology_clinical_reproduction.ipynb explanation; exact accepted PRISM counts/checksums are not recoverable from a durable checked report, and the removed builder test is intentionally not cited as current evidence.
# - **bounded fixture:** not available. Exact accepted source-family count/checksum evidence is not present in a durable checked report; this is an explanatory gap, not evidence of zero output. The tracked PRISM builder requires six release-selected local input tables; a bounded Figshare acquisition command that materializes and checksums all six is not yet tracked.
#
# **Produced artifacts**
#   - `immutable staged viability features and cell_line_responds_to_molecule edges/evidence`
#
# **Manual production/acquisition command (documentation only; never executed here)**
#
# ```text
# Historical accepted lane at commit 1cb1c314e24a1d7a1386ef1b98b9cab395557283: uv run python -m manage_db.build_staged_prism_20q2 --curve-counts <curve_counts.csv> --treatment-info <treatment_info.csv> --lfc <lfc.csv> --pool <pool.csv> --cell-lines <cell_line.parquet> --molecules <molecule.parquet> --output-dir <task-local-output> --release PRISM-20Q2-Secondary. The builder is intentionally not retained by this rescope.
# ```

# %% [markdown]
# <a id="source-cellosaurus"></a>
# ## Cellosaurus OBO
#
# - **status:** `canonical` — canonical cell-line identity/origin context and official cell-line textual summaries from Cellosaurus release 55.0
# - **release/snapshot:** Cellosaurus release 55.0; date=03:31:2026 12:00 (accepted official text-feature source)
# - **source and access:** https://ftp.expasy.org/databases/cellosaurus/cellosaurus.obo — ExPASy Cellosaurus OBO download
# - **licence/citation:** Cellosaurus CC BY 4.0; cite Cellosaurus and preserve attribution/change notice
# - **raw cache template:** `artifacts/cache/<task-id>/cellosaurus/cellosaurus.obo`
# - **preprocessing entrypoint:** `manage_db/build_textual_summary_features.py; txdata_download.py`
# - **mapping:** Cellosaurus and DepMap xrefs; unmatched comments/identities remain rejects
# - **rejects/conflicts/evidence:** Cellosaurus and DepMap xrefs; unmatched comments/identities remain rejects
# - **validation evidence:** reproduce/19_node_sequence_text_features_summary.ipynb and docs/textual_summary_features.md: official cell_line_textual_summary has 1,140 rows / 1,183 endpoint nodes (96.37%), source Cellosaurus OBO comments via DepMap ACH xrefs, release 55.0; validation reported endpoint misses, missing text, over-max text rows 0.
# - **bounded fixture:** available. Exact accepted source-family count/checksum evidence is not present in a durable checked report; this is an explanatory gap, not evidence of zero output. Bounded demonstration is provided using a pure parser/schema function from the tracked repository.
#
# **Produced artifacts**
#   - `canonical cell-line identity/origin context`
#   - `official cell_line_textual_summary feature table`
#
# **Manual production/acquisition command (documentation only; never executed here)**
#
# ```text
# No complete current acquisition command is tracked. Use the immutable URL/file identifiers above, record bytes and SHA-256 in a task-local manifest, then invoke the preprocessing entrypoint separately.
# ```

# %% [markdown]
# <a id="source-clinicaltrials-gov"></a>
# ## ClinicalTrials.gov API v2
#
# - **status:** `staged` — staged trial metadata, molecule-disease edge evidence and text-feature sidecars
# - **release/snapshot:** ClinicalTrials.gov API v2 response chunks used by the staged candidate; fetch timestamp is the snapshot identifier
# - **source and access:** https://clinicaltrials.gov/data-api/api — frozen API v2 JSON response chunks
# - **licence/citation:** ClinicalTrials.gov/NLM public API; verify redistribution/attribution terms before promotion
# - **raw cache template:** `artifacts/staged/<task-id>/notebook_runs/clinicaltrials/raw`
# - **preprocessing entrypoint:** `manage_db/stage_clinicaltrials_gov_production_candidate.py`
# - **mapping:** NCT IDs source-asserted by OpenTargets clinical evidence; fetch misses and unsupported edge links reported
# - **rejects/conflicts/evidence:** NCT IDs source-asserted by OpenTargets clinical evidence; fetch misses and unsupported edge links reported
# - **validation evidence:** 28_cell_line_pharmacology_clinical_reproduction.ipynb; focused test command: uv run --group dev pytest -q tests/test_stage_clinicaltrials_gov_production_candidate.py; exact accepted counts/checksums are not recoverable from a durable checked report where noted in gap.
# - **bounded fixture:** not available. Exact accepted source-family count/checksum evidence is not present in a durable checked report; this is an explanatory gap, not evidence of zero output. The builder has no complete checked-raw-snapshot CLI and may fetch missing studies; offline replay is deferred.
#
# **Produced artifacts**
#   - `staged trial metadata, molecule-disease edge evidence and text-feature sidecars`
#
# **Manual production/acquisition command (documentation only; never executed here)**
#
# ```text
# No complete offline replay command is tracked; manage_db.stage_clinicaltrials_gov_production_candidate may fetch missing studies and is therefore documentation-only here.
# ```

# %% [markdown]
# ## Bounded executable illustration
#
# The following cell exercises real repository behavior on synthetic input and writes only inside a temporary directory.

# %%
import json
import tempfile
from pathlib import Path

from manage_db.build_staged_cell_line_assays import _parse_crispr_gene_column
from manage_db.build_textual_summary_features import parse_cellosaurus_obo

assert _parse_crispr_gene_column("TP53 (7157)") == ("TP53", "7157")
assert _parse_crispr_gene_column("malformed") is None
fixture = """format-version: 1.2
data-version: 56
! Licensing information: CC BY 4.0

[Term]
id: CVCL_0023
name: A-549
xref: DepMap:ACH-000681
comment: Human lung carcinoma cell line.
"""
with tempfile.TemporaryDirectory() as tmp:
    fixture_path = Path(tmp) / "cellosaurus.obo"
    fixture_path.write_text(fixture)
    records, header = parse_cellosaurus_obo(fixture_path)
    result_path = Path(tmp) / "cellosaurus_demo.json"
    result_path.write_text(json.dumps({"records": records, "header": header}))
    result = json.loads(result_path.read_text())
assert result["records"][0]["depmap_xrefs"] == ["ACH-000681"]
assert result["header"]["data-version"] == "56"
result
