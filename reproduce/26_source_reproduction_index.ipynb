# %% [markdown]
# # Jouvence source reproduction index
#
# Canonical denominator, historical acquisition, and honest replay gaps for the base KG sources.
#
# This is explanatory reproduction plus a bounded local illustration—not a production runner. Production commands below are inert text. Code cells use only synthetic input, temporary directories, and pure tracked parsing/schema functions. They perform no shell, subprocess, network, cloud, GCS, LaminDB, canonical-path, or production-builder execution.
#
# Status describes the accepted artifact, independently of replay completeness: `canonical`, `official`, `staged`, `deferred`, or `not_reproducible_yet`.

# %% [markdown]
# ## Reconciled denominator
#
# Canonical source families (12): `biogrid_5_0_258`, `cellosaurus`, `cellxgene`, `depmap_ccle`, `encode_re2g`, `ensembl`, `gtex`, `hpa_25_1`, `hpo_ontology`, `opentargets_26_03`, `reactome_go`, `txgnn_legacy_sources`.
#
# Evidence used to derive the denominator:
# - `docs/source_measure_edge_matrix.md`
# - `docs/part2_biogrid_ppi_canonical_promotion_report.md`
# - `docs/protein_textual_summary_official_promotion_report.md`
# - `reproduce/09_source_native_ingestion_index.ipynb`
# - `reproduce/13_non_remap_canonical_promotion_summary.ipynb`
# - `reproduce/19_node_sequence_text_features_summary.ipynb`
# - `TODO.md`

# %% [markdown]
# <a id="source-opentargets-26-03"></a>
# ## OpenTargets Platform 26.03
#
# - **status:** `canonical` — canonical nodes, OpenTargets-derived edges/evidence, genomic and association relations
# - **release/snapshot:** Open Targets Platform 26.03
# - **source and access:** https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/ — release-pinned EBI FTP Parquet download
# - **licence/citation:** Open Targets Platform data downloads; cite Open Targets and retain dataset-level provenance
# - **raw cache template:** `artifacts/cache/<task-id>/opentargets/26.03`
# - **preprocessing entrypoint:** `manage_db/ingest_opentargets.py`
# - **mapping:** ENSG/ENST/ENSP/ChEMBL/EFO endpoint maps; per-dataset rejects and endpoint anti-joins
# - **rejects/conflicts/evidence:** ENSG/ENST/ENSP/ChEMBL/EFO endpoint maps; per-dataset rejects and endpoint anti-joins
# - **validation evidence:** 07_opentargets_edges_and_evidence.ipynb; focused test command: uv run --group dev pytest -q tests/test_reproduction_source_inventory.py; exact accepted counts/checksums are not recoverable from a durable checked report where noted in gap.
# - **bounded fixture:** not available. Exact accepted source-family count/checksum evidence is not present in a durable checked report; this is an explanatory gap, not evidence of zero output. No small checked-in source-native fixture exercises this family yet; explanation and accepted validation evidence are provided without claiming replay.
#
# **Produced artifacts**
#   - `canonical nodes, OpenTargets-derived edges/evidence, genomic and association relations`
#
# **Manual production/acquisition command (documentation only; never executed here)**
#
# ```text
# uv run python -m manage_db.ingest_opentargets --data-dir artifacts/cache/<task-id>/opentargets --release 26.03
# ```

# %% [markdown]
# <a id="source-txgnn-legacy-sources"></a>
# ## TxData/TxGNN legacy source bundle
#
# - **status:** `canonical` — legacy canonical nodes/edges including DrugBank/CTD, ontology, expression and provenance-retained source subsets
# - **release/snapshot:** TxData Dataverse DOI 10.7910/DVN/CNQV69; file IDs 7144484, 7144482, 7144483
# - **source and access:** https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69 — Harvard Dataverse DOI and immutable file IDs
# - **licence/citation:** TxGNN/TxData release and upstream source licenses/citations; do not erase source-specific attribution
# - **raw cache template:** `artifacts/cache/<task-id>/txgnn_legacy`
# - **preprocessing entrypoint:** `manage_db/export_kg.py`
# - **mapping:** legacy IDs normalized to KG namespaces; source evidence gaps remain policy-labeled rather than fabricated
# - **rejects/conflicts/evidence:** legacy IDs normalized to KG namespaces; source evidence gaps remain policy-labeled rather than fabricated
# - **validation evidence:** 06_build_core_edges_and_evidence.ipynb; focused test command: uv run --group dev pytest -q tests/test_reproduction_source_inventory.py; exact accepted counts/checksums are not recoverable from a durable checked report where noted in gap.
# - **bounded fixture:** not available. Exact accepted source-family count/checksum evidence is not present in a durable checked report; this is an explanatory gap, not evidence of zero output. preprocessing replay remains notebook-only
#
# **Produced artifacts**
#   - `legacy canonical nodes/edges including DrugBank/CTD, ontology, expression and provenance-retained source subsets`
#
# **Manual production/acquisition command (documentation only; never executed here)**
#
# ```text
# No complete current acquisition command is tracked. Use the immutable URL/file identifiers above, record bytes and SHA-256 in a task-local manifest, then invoke the preprocessing entrypoint separately.
# ```

# %% [markdown]
# <a id="source-encode-re2g"></a>
# ## ENCODE rE2G
#
# - **status:** `canonical` — canonical enhancer nodes and enhancer_regulates_gene edges/evidence
# - **release/snapshot:** ENCODE rE2G snapshot bundled in Open Targets Platform 26.03
# - **source and access:** https://www.encodeproject.org/ — Open Targets 26.03 bundled Parquet
# - **licence/citation:** ENCODE and OpenTargets terms/citations; preserve biosample and file provenance
# - **raw cache template:** `artifacts/cache/<task-id>/opentargets/26.03/enhancer_to_gene`
# - **preprocessing entrypoint:** `manage_db/ingest_opentargets.py`
# - **mapping:** enhancer intervals and ENSG endpoints; scores/context retained; endpoint anti-joins must be zero
# - **rejects/conflicts/evidence:** enhancer intervals and ENSG endpoints; scores/context retained; endpoint anti-joins must be zero
# - **validation evidence:** reproduce/07_opentargets_edges_and_evidence.ipynb documents the Open Targets 26.03 rE2G mapping; exact accepted per-object counts/checksums are not recoverable from a durable checked report.
# - **bounded fixture:** not available. Exact accepted source-family count/checksum evidence is not present in a durable checked report; this is an explanatory gap, not evidence of zero output. dataset replay remains notebook-only
#
# **Produced artifacts**
#   - `canonical enhancer nodes and enhancer_regulates_gene edges/evidence`
#
# **Manual production/acquisition command (documentation only; never executed here)**
#
# ```text
# No complete current command. Historical route: manage_db/ingest_opentargets.py
# ```

# %% [markdown]
# <a id="source-gtex"></a>
# ## GTEx tissue-expression snapshot in the TxGNN legacy bundle
#
# - **status:** `canonical` — canonical tissue_expresses_gene
# - **release/snapshot:** GTEx snapshot distributed in TxData DOI 10.7910/DVN/CNQV69; upstream release not recoverable
# - **source and access:** https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69 — TxData Dataverse bundle
# - **licence/citation:** GTEx data/citation policy and TxData provenance
# - **raw cache template:** `artifacts/cache/<task-id>/txgnn_legacy`
# - **preprocessing entrypoint:** `txdata_download.py; manage_db/export_kg.py`
# - **mapping:** tissue and ENSG endpoints; expression modality remains RNA/gene-level
# - **rejects/conflicts/evidence:** tissue and ENSG endpoints; expression modality remains RNA/gene-level
# - **validation evidence:** 06_build_core_edges_and_evidence.ipynb; focused test command: uv run --group dev pytest -q tests/test_reproduction_source_inventory.py; exact accepted counts/checksums are not recoverable from a durable checked report where noted in gap.
# - **bounded fixture:** not available. Exact accepted source-family count/checksum evidence is not present in a durable checked report; this is an explanatory gap, not evidence of zero output. typed GTEx replay is not tracked
#
# **Produced artifacts**
#   - `canonical tissue_expresses_gene`
#
# **Manual production/acquisition command (documentation only; never executed here)**
#
# ```text
# No complete current acquisition command is tracked. Use the immutable URL/file identifiers above, record bytes and SHA-256 in a task-local manifest, then invoke the preprocessing entrypoint separately.
# ```

# %% [markdown]
# <a id="source-cellxgene"></a>
# ## cell-type expression snapshot in the TxGNN legacy bundle
#
# - **status:** `canonical` — canonical cell_type_expresses_gene
# - **release/snapshot:** cell-type expression snapshot distributed in TxData DOI 10.7910/DVN/CNQV69; constituent releases not recoverable
# - **source and access:** https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69 — TxData Dataverse bundle
# - **licence/citation:** cellxgene and constituent dataset licenses/citations
# - **raw cache template:** `artifacts/cache/<task-id>/txgnn_legacy`
# - **preprocessing entrypoint:** `txdata_download.py; manage_db/export_kg.py`
# - **mapping:** cell ontology/context and ENSG endpoints; no gene-to-protein projection
# - **rejects/conflicts/evidence:** cell ontology/context and ENSG endpoints; no gene-to-protein projection
# - **validation evidence:** 06_build_core_edges_and_evidence.ipynb; focused test command: uv run --group dev pytest -q tests/test_reproduction_source_inventory.py; exact accepted counts/checksums are not recoverable from a durable checked report where noted in gap.
# - **bounded fixture:** not available. Exact accepted source-family count/checksum evidence is not present in a durable checked report; this is an explanatory gap, not evidence of zero output. typed cellxgene replay is not tracked
#
# **Produced artifacts**
#   - `canonical cell_type_expresses_gene`
#
# **Manual production/acquisition command (documentation only; never executed here)**
#
# ```text
# No complete current acquisition command is tracked. Use the immutable URL/file identifiers above, record bytes and SHA-256 in a task-local manifest, then invoke the preprocessing entrypoint separately.
# ```

# %% [markdown]
# ## Bounded executable illustration
#
# The following cell exercises real repository behavior on synthetic input and writes only inside a temporary directory.

# %%
import json
import tempfile
from pathlib import Path

status_counts = {'canonical': 12, 'deferred': 4, 'official': 4, 'staged': 6}
assert sum(status_counts.values()) == 26
assert status_counts["canonical"] == 12
with tempfile.TemporaryDirectory() as tmp:
    summary_path = Path(tmp) / "source_inventory_summary.json"
    summary_path.write_text(json.dumps(status_counts, sort_keys=True))
    round_trip = json.loads(summary_path.read_text())
assert round_trip == status_counts
round_trip
